# %%
import os
os.environ['CUDA_DEVICE_ORDER']="PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES']="0"

from tensorflow.keras.models import Model
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tensorflow.keras.optimizers import RMSprop

# %%
import tensorflow as tf
physical_devices= tf.config.list_physical_devices('GPU')
try: 
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
    print('Failed to limit GPU memory')
# Out:
# Failed to limit GPU memory

# %%
data_dir = 'D:/DatasetMuseumFix/'

# Image data generator with rescaling
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

# Training dataset
train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',  
    subset='training' 
)

# Validation dataset
validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',  
    subset='validation'
)
# Out:
# Found 4188 images belonging to 13 classes.
# Found 1794 images belonging to 13 classes.

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
preds = Dense(13, activation='softmax')(x)  

model = Model(inputs=base_model.input, outputs=preds)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_2[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
#  global_average_pooling2d_1 (Gl  (None, 1280)        0           ['out_relu[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 512)          655872      ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_5 (Dense)                (None, 256)          131328      ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 128)          32896       ['dense_5[0][0]']
#
#  dense_7 (Dense)                (None, 9)            1161        ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 3,079,241
# Trainable params: 3,045,129
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
for layers in model.layers[:-5]:
    layers.trainable = False

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_4[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
#  global_average_pooling2d_3 (Gl  (None, 1280)        0           ['out_relu[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 512)          655872      ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_13 (Dense)               (None, 256)          131328      ['dense_12[0][0]']
#
#  dense_14 (Dense)               (None, 128)          32896       ['dense_13[0][0]']
#
#  dense_15 (Dense)               (None, 13)           1677        ['dense_14[0][0]']
#
# ==================================================================================================
# Total params: 3,079,757
# Trainable params: 821,773
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
opt = Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=20
)
# Out:
# Epoch 1/20
# 131/131 [==============================] - 290s 2s/step - loss: 5.2303e-05 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9799
# Epoch 2/20
# 131/131 [==============================] - 235s 2s/step - loss: 7.2555e-06 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9805
# Epoch 3/20
# 131/131 [==============================] - 222s 2s/step - loss: 3.3281e-06 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9788
# Epoch 4/20
# 131/131 [==============================] - 205s 2s/step - loss: 2.2404e-06 - accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 0.9794
# Epoch 5/20
# 131/131 [==============================] - 210s 2s/step - loss: 1.6262e-06 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9805
# Epoch 6/20
# 131/131 [==============================] - 195s 1s/step - loss: 1.2251e-06 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9805
# Epoch 7/20
# 131/131 [==============================] - 190s 1s/step - loss: 9.5919e-07 - accuracy: 1.0000 - val_loss: 0.0588 - val_accuracy: 0.9794
# Epoch 8/20
# 131/131 [==============================] - 197s 2s/step - loss: 7.7377e-07 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9788
# Epoch 9/20
# 131/131 [==============================] - 193s 1s/step - loss: 6.3427e-07 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9788
# Epoch 10/20
# 131/131 [==============================] - 196s 2s/step - loss: 5.3063e-07 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9805
# Epoch 11/20
# 131/131 [==============================] - 202s 2s/step - loss: 4.4809e-07 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 0.9805
# Epoch 12/20
# 131/131 [==============================] - 204s 2s/step - loss: 3.8384e-07 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9805
# Epoch 13/20
# 131/131 [==============================] - 210s 2s/step - loss: 3.3019e-07 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9805
# Epoch 14/20
# 131/131 [==============================] - 215s 2s/step - loss: 2.8889e-07 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 0.9805
# Epoch 15/20
# 131/131 [==============================] - 212s 2s/step - loss: 2.5316e-07 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9805
# Epoch 16/20
# 131/131 [==============================] - 201s 2s/step - loss: 2.2182e-07 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9805
# Epoch 17/20
# 131/131 [==============================] - 194s 1s/step - loss: 1.9669e-07 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9805
# Epoch 18/20
# 131/131 [==============================] - 213s 2s/step - loss: 1.7483e-07 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9805
# Epoch 19/20
# 131/131 [==============================] - 214s 2s/step - loss: 1.5678e-07 - accuracy: 1.0000 - val_loss: 0.0589 - val_accuracy: 0.9805
# Epoch 20/20
# 131/131 [==============================] - 217s 2s/step - loss: 1.3939e-07 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 0.9805

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.ylim([0, 1])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.ylim([0, 5])
plt.show()

# %%
from PIL import Image

folder = 'D:/TestingGambarRandom/sculpture'
dirs = os.listdir(folder)
print(folder)

for item in dirs:
    fullpath = os.path.join(folder, item)
    if os.path.isfile(fullpath):
        img = Image.open(fullpath).convert('RGB')
        img = img.resize((224, 224))
        img_array = np.array(img) / 255.0 
        img_array = np.expand_dims(img_array, axis=0)
        predictions = model.predict(img_array)
        predicted_class = np.argmax(predictions)
        print("Predicted Class:", predicted_class)

        if predicted_class==1:
            print("Bali Following Independence")
        elif predicted_class==2:
            print("Dang Hyang Nirartha")
        elif predicted_class==3:
            print("Sagung Wah In Preparation To Attack The Dutch")
        elif predicted_class==4:
            print("Spreading The News of The Proclamation of Indonesia")
        elif predicted_class==5:
            print("The Battle of Jagaraga")
        elif predicted_class==6:
            print("The Crowning Of Sri Kresna Kepakisan")
        elif predicted_class==7:
            print("The Establishment Of Indonesian People Struggling Board Of Sunda Kecil")
        elif predicted_class==8:
            print("The Naval Battle In Bali Strait")
        elif predicted_class==9:
            print("The Rise Of Youth Organization")
        elif predicted_class==10:
            print("Painting I Gusti Ngurah Rai")
        elif predicted_class==11:
            print("Painting Menyambut Proklamasi Kemerdekaan RI")
        elif predicted_class==12:
            print("Painting Ngurah Rai Mengatur Siasat Tempur")
        else:
            print("RandomData")
# Out:
# D:/TestingGambarRandom/sculpture
# 1/1 [==============================] - 2s 2s/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 115ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 95ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 92ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 61ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 64ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 60ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 109ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 131ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 120ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 100ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 75ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 72ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 90ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 72ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 71ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 64ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 66ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 60ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 65ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 67ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 61ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 64ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 69ms/step
# Predicted Class: 10
# Painting I Gusti Ngurah Rai
# 1/1 [==============================] - 0s 77ms/step
# Predicted Class: 10
# Painting I Gusti Ngurah Rai
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 79ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 61ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 61ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 65ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 67ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 100ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 88ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 114ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 86ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 137ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 67ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 79ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 61ms/step
# Predicted Class: 8
# The Naval Battle In Bali Strait
# 1/1 [==============================] - 0s 61ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 127ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 109ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 117ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 64ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 52ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 63ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 147ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 77ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 96ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 103ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 107ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 105ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 98ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 100ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 161ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 88ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 101ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 98ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 92ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 10
# Painting I Gusti Ngurah Rai
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 76ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 75ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 61ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 76ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 60ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 67ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 103ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 92ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 63ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 106ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 92ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 96ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 90ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 110ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 66ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 114ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 63ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 66ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 64ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 63ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 101ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 103ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 71ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 163ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 110ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 106ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 75ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 63ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 104ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 72ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 63ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 98ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 88ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 96ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 101ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 100ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 145ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 117ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 183ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 119ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 132ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 148ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 92ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 228ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 116ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 107ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 1/1 [==============================] - 0s 111ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 8
# The Naval Battle In Bali Strait
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 11
# Painting Menyambut Proklamasi Kemerdekaan RI
# 1/1 [==============================] - 0s 69ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 93ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 72ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 88ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 97ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 128ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 116ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 110ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 114ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 105ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 117ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 101ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 86ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 92ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 93ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 98ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 122ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 134ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 106ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 64ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 123ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 125ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 136ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 111ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 187ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 137ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 121ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 107ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 299ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 115ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 116ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 100ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 100ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 104ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 107ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 86ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 97ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 90ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 121ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 72ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 71ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 87ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 86ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 90ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 10
# Painting I Gusti Ngurah Rai
# 1/1 [==============================] - 0s 71ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 88ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 79ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 87ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 66ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 2
# Dang Hyang Nirartha
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 75ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 90ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 77ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 92ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 75ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 87ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 97ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 65ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 109ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 86ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 130ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 121ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 126ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 144ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 109ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 111ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 98ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 132ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 105ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 117ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 86ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 151ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 109ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 108ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 126ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 104ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 120ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 127ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 110ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 109ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 88ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 72ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 88ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 2
# Dang Hyang Nirartha
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 107ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 113ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 77ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 110ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 104ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 113ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 79ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 127ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 104ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 87ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 97ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 58ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 93ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 130ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 113ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 103ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 101ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 315ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 86ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 57ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 72ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 107ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 110ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 100ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 103ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 106ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 79ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 77ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 96ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 94ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 141ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 191ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 119ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 141ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 84ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 90ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 59ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 69ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 58ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 53ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 76ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 63ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 71ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 60ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 71ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 67ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 88ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 77ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 82ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 51ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 63ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 95ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 93ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 64ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 67ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 69ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 69ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 76ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 98ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 97ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 91ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 231ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 103ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 69ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 76ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 56ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 78ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 65ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 66ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 71ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 74ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 80ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 66ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 58ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 85ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 81ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 83ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 89ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 62ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 70ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 101ms/step
# Predicted Class: 0
# RandomData
# 1/1 [==============================] - 0s 100ms/step
# Predicted Class: 0
# RandomData

# %%
from tensorflow.keras.models import load_model
import pathlib

model.save('model_fix.h5')
loaded_model = load_model('model_fix.h5')


export_dir = 'C:/Users/user/miniconda3/CapstoneProject'
tf.saved_model.save(model, export_dir)

converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path('C:/Users/user/miniconda3/CapstoneProject/model_fix.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/user/miniconda3/CapstoneProject\assets
# INFO:tensorflow:Assets written to: C:/Users/user/miniconda3/CapstoneProject\assets
# 12146656
